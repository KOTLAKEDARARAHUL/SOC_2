# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\kedar\Downloads\Linear_regr_Salary_dataset.csv")
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.shape
# Out:
# (30, 3)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df[["YearsExperience"]]
y=df["Salary"]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=101)
x_train,x_test,y_train,y_test
# Out:
# (    YearsExperience
#  1               1.4
#  19              6.1
#  22              8.0
#  12              4.1
#  5               3.0
#  14              4.6
#  0               1.2
#  21              7.2
#  4               2.3
#  8               3.3
#  13              4.2
#  9               3.8
#  15              5.0
#  29             10.6
#  23              8.3
#  6               3.1
#  17              5.4
#  11              4.1,
#      YearsExperience
#  20              6.9
#  24              8.8
#  7               3.3
#  18              6.0
#  2               1.6
#  27              9.7
#  26              9.6
#  16              5.2
#  25              9.1
#  28             10.4
#  10              4.0
#  3               2.1,
#  1      46206.0
#  19     93941.0
#  22    101303.0
#  12     56958.0
#  5      56643.0
#  14     61112.0
#  0      39344.0
#  21     98274.0
#  4      39892.0
#  8      64446.0
#  13     57082.0
#  9      57190.0
#  15     67939.0
#  29    121873.0
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 91487.32335452, 109831.9872175 ,  56729.0128773 ,  82797.74573522,
#         40315.36626306, 118521.56483681, 117556.05621244,  75073.67674028,
#        112728.5130906 , 125280.12520738,  63487.57324787,  45142.90938489])

# %%
y_test
# Out:
# 20     91739.0
# 24    109432.0
# 7      54446.0
# 18     81364.0
# 2      37732.0
# 27    112636.0
# 26    116970.0
# 16     66030.0
# 25    105583.0
# 28    122392.0
# 10     63219.0
# 3      43526.0
# Name: Salary, dtype: float64

# %%
import numpy as np
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,np.round(y_pred))
acc
# Out:
# 0.0

# %%
inputdata=[[14.5]]
prediction=model.predict(inputdata)
prediction
# Out:
# C:\Users\kedar\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([164865.97880644])

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 16085205.26610922

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lmplot(x="YearsExperience",y="Salary",data=df,scatter_kws={"color":"yellow"},line_kws={"color":"red"})
ax=plt.gca()
sns.set_style("darkgrid")
plt.gca().set_facecolor('black')
ax.tick_params(axis='x',colors='blue')
ax.tick_params(axis='y',colors='red')
# Out:
# C:\Users\kedar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_1=pd.read_csv(r"C:\Users\kedar\Downloads\LR_Student_Performance.csv")
df_1
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df_1.shape
# Out:
# (10000, 6)

# %%
df_1.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
dup=df_1.duplicated()
df_1[dup]
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 915               9               52                         No            5
# 1477              7               61                        Yes            6
# 1601              5               99                         No            7
# 1786              2               62                        Yes            9
# 2026              5               87                        Yes            6
# ...             ...              ...                        ...          ...
# 9644              4               91                        Yes            4
# 9940              8               95                         No            5
# 9954              6               97                         No            8
# 9966              1               41                         No            7
# 9985              8               99                         No            5
#
# ...

# %%
dup.sum()
# Out:
# 127

# %%
print("Before duplicating duplicates:",df_1.shape)
df1.drop_duplicates(inplace=True)
print("After dropping duplicates:",df_1.shape)
# Out:
# Before duplicating duplicates: (10000, 6)
# After dropping duplicates: (9873, 6)

# %%
response=df_1['Performance Index']
response.dtype
# Out:
# dtype('float64')

# %%
plt.plot(response.index,response)
plt.xlabel('Index')
plt.ylabel('Performance Index')
# Out:
# Text(0, 0.5, 'Performance Index')

# %%
sns.jointplot(x=response.index,y='Performance Index',data=df_1,kind='reg')

# %%
sns.jointplot(x=response.index,y='Performance Index',data=df_1,kind='kde')

# %%
sns.violinplot(response)
# Out:
# <Axes: >

# %%
df_1['Performance Index'].min()
# Out:
# 10.0

# %%
df_1['Performance Index'].max()
# Out:
# 100.0

# %%
df_1['Performance Index'].value_counts()
# Out:
# Performance Index
# 67.0     182
# 45.0     181
# 56.0     179
# 49.0     177
# 40.0     176
#         ...
# 14.0       7
# 99.0       6
# 11.0       5
# 100.0      3
# 10.0       1
# Name: count, Length: 91, dtype: int64

# %%
df_1['Hours Studied'].min()
# Out:
# 1

# %%
df_1['Hours Studied'].max()
# Out:
# 9

# %%
df_1['Hours Studied'].unique()
# Out:
# array([7, 4, 8, 5, 3, 6, 2, 1, 9], dtype=int64)

# %%
df_1['Hours Studied'].value_counts()
# Out:
# Hours Studied
# 1    1133
# 6    1122
# 7    1118
# 3    1110
# 9    1099
# 2    1077
# 8    1074
# 4    1071
# 5    1069
# Name: count, dtype: int64

# %%
x=df_1["Hours Studied"]
sns.histplot(x)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Count'>

# %%
x=df_1['Hours Studied']
sns.histplot(x,color='green',kde=True)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Count'>

# %%
sns.histplot(y="Performance Index",x="Hours Studied",data=df_1)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
sns.barplot(y="Performance Index",x="Hours Studied",data=df_1)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
df_1.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
sns.histplot(df_1["Extracurricular Activities"])
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='Count'>

# %%
sns.boxplot(x=df_1["Hours Studied"],y=df_1["Performance Index"])
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
df_1["Extracurricular Activities"]=df_1["Extracurricular Activities"].map({'Yes':1,'No':0})
df_1
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
sns.histplot(df_1["Extracurricular Activities"])
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='Count'>

# %%
df_1.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
y=df_1['Performance Index']
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
x=df_1[['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
       'Sleep Hours', 'Sample Question Papers Practiced']]
x
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=101)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([44.39182655, 96.13564305, 30.57978946, ..., 31.23011643,
#        67.75874112, 28.10993149])

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,np.round(y_pred))
acc
# Out:
# 0.2015

# %%
data=[[8,85,1,6,6]]
prediction=model.predict(data)
prediction
# Out:
# C:\Users\kedar\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([79.94425089])

# %%
from sklearn.linear_model import Ridge
clf=Ridge()
clf.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array([44.39197551, 96.13511347, 30.5798681 , ..., 31.23037878,
#        67.75871088, 28.11000109])

# %%
clf.score(x_test,y_test)
# Out:
# 0.9888235045787498

# %%
df_2=pd.read_csv(r"C:\Users\kedar\Downloads\framingham.csv")
df_2
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df_2.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')
